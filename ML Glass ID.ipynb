# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv")

# %%
df.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
print(df.columns)
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
column=['ID number','Refractive index','Sodium', 'Magnesium','Aluminum','Silicon','Potassium','Calcium', 'Barium', 'Iron', 'Type of glass']
df='https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv'
df1=pd.read_csv(df, skiprows=1, names = column)
print(df1.columns)
# Out:
# Index(['ID number', 'Refractive index', 'Sodium', 'Magnesium', 'Aluminum',
#        'Silicon', 'Potassium', 'Calcium', 'Barium', 'Iron', 'Type of glass'],
#       dtype='object')

# %%
df1
# Out:
#      ID number  Refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 0            2           1.51761   13.89       3.60      1.36    72.73
# 1            3           1.51618   13.53       3.55      1.54    72.99
# 2            4           1.51766   13.21       3.69      1.29    72.61
# 3            5           1.51742   13.27       3.62      1.24    73.08
# 4            6           1.51596   12.79       3.61      1.62    72.97
# ..         ...               ...     ...        ...       ...      ...
# 208        210           1.51623   14.14       0.00      2.88    72.61
# 209        211           1.51685   14.92       0.00      1.99    73.06
# 210        212           1.52065   14.36       0.00      2.02    73.42
# 211        213           1.51651   14.38       0.00      1.94    73.61
# 212        214           1.51711   14.23       0.00      2.08    73.36
#
#      Potassium  Calcium  Barium  Iron  Type of glass
# 0         0.48     7.83    0.00  0.00              1
# ...

# %%
df1.shape
# Out:
# (213, 11)

# %%
df1.isna().sum()
# Out:
# ID number           0
# Refractive index    0
# Sodium              0
# Magnesium           0
# Aluminum            0
# Silicon             0
# Potassium           0
# Calcium             0
# Barium              0
# Iron                0
# Type of glass       0
# dtype: int64

# %%
df1.skew()
# Out:
# ID number           0.000000
# Refractive index    1.639658
# Sodium              0.457318
# Magnesium          -1.154323
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           6.549276
# Calcium             2.040591
# Barium              3.406749
# Iron                1.747173
# Type of glass       1.108861
# dtype: float64

# %%
#EDA

# %%
# Dropping the column "Id"

# %%
df2=df1.drop(columns='ID number',inplace=False)

# %%
df2.head()
# Out:
#    Refractive index  Sodium  Magnesium  Aluminum  Silicon  Potassium  Calcium  \
# 0           1.51761   13.89       3.60      1.36    72.73       0.48     7.83
# 1           1.51618   13.53       3.55      1.54    72.99       0.39     7.78
# 2           1.51766   13.21       3.69      1.29    72.61       0.57     8.22
# 3           1.51742   13.27       3.62      1.24    73.08       0.55     8.07
# 4           1.51596   12.79       3.61      1.62    72.97       0.64     8.07
#
#    Barium  Iron  Type of glass
# 0     0.0  0.00              1
# 1     0.0  0.00              1
# 2     0.0  0.00              1
# 3     0.0  0.00              1
# 4     0.0  0.26              1

# %%
df2.isnull().sum()
# Out:
# Refractive index    0
# Sodium              0
# Magnesium           0
# Aluminum            0
# Silicon             0
# Potassium           0
# Calcium             0
# Barium              0
# Iron                0
# Type of glass       0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Refractive index  213 non-null    float64
#  1   Sodium            213 non-null    float64
#  2   Magnesium         213 non-null    float64
#  3   Aluminum          213 non-null    float64
#  4   Silicon           213 non-null    float64
#  5   Potassium         213 non-null    float64
#  6   Calcium           213 non-null    float64
#  7   Barium            213 non-null    float64
#  8   Iron              213 non-null    float64
#  9   Type of glass     213 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df2.nunique()
# Out:
# Refractive index    177
# Sodium              142
# Magnesium            93
# Aluminum            117
# Silicon             132
# Potassium            65
# Calcium             143
# Barium               34
# Iron                 32
# Type of glass         6
# dtype: int64

# %%
# Visualization
# Histogram: To check for the skewness of the continuous variables

# %%
df2.hist(column=['Refractive index', 'Sodium', 'Magnesium', 'Aluminum', 'Silicon', 'Potassium', 'Calcium', 'Barium', 'Iron'],figsize=(12,12))
plt.show()

# %%
df2[['Refractive index', 'Sodium', 'Magnesium', 'Aluminum', 'Silicon', 'Potassium', 'Calcium', 'Barium', 'Iron']].skew()
# Out:
# Refractive index    1.639658
# Sodium              0.457318
# Magnesium          -1.154323
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           6.549276
# Calcium             2.040591
# Barium              3.406749
# Iron                1.747173
# dtype: float64

# %% [markdown]
# # BoxCox transformation: To reduce skewness of the variables

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
from scipy.stats import boxcox
df2=pd.DataFrame()
for i in df1[['Refractive index', 'Sodium', 'Magnesium', 'Aluminum', 'Silicon', 'Potassium', 'Calcium', 'Barium', 'Iron']]:
    coll, lambda_value = boxcox(df1[i]+1)
    df2[i]=coll
df2.skew()
# Out:
# Refractive index    0.000000
# Sodium             -0.009526
# Magnesium          -0.911150
# Aluminum            0.000874
# Silicon             0.133867
# Potassium          -0.075233
# Calcium            -0.207808
# Barium              1.817526
# Iron                0.852473
# dtype: float64

# %%
df2.hist(column=['Refractive index', 'Sodium', 'Magnesium', 'Aluminum', 'Silicon', 'Potassium', 'Calcium', 'Barium', 'Iron'],figsize=(15,15))
plt.show()

# %%
# Heatmap

# %%
plt.figure(figsize=(18,18))
sns.heatmap(abs(df1.corr()), annot=True)
plt.show()

# %%
df1.corr()
# Out:
#                ID number        RI  Na(4-10)        Mg        Si         k  \
# ID number       1.000000 -0.193436 -0.117543 -0.405671 -0.540010 -0.287900
# RI             -0.193436  1.000000 -0.279296  0.157928 -0.068519 -0.265520
# Na(4-10)       -0.117543 -0.279296  1.000000 -0.451146 -0.168378  0.003411
# Mg             -0.405671  0.157928 -0.451146  1.000000 -0.009226  0.324484
# Si             -0.540010 -0.068519 -0.168378 -0.009226  1.000000 -0.197684
# k              -0.287900 -0.265520  0.003411  0.324484 -0.197684  1.000000
# Ca              0.812495 -0.275314 -0.420394 -0.260372 -0.210141 -0.318649
# Ba              0.001062  0.327233 -0.497804  0.478936 -0.104361 -0.043790
# Fe              0.145791 -0.240802  0.102150 -0.076456 -0.097674 -0.009586
# Type of glass  -0.161322  0.504983 -0.700392  0.597754  0.147767 -0.012765
#
#                      Ca        Ba        Fe  Type of glass
# ID number      0.812495  0.001062  0.145791      -0.161322
# ...

# %%
plt.figure(figsize= (20,15))
sns.heatmap(df1.corr(),linewidths = 0.1,fmt = ".1g",linecolor = "black" ,annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
# BAR Plot

# %%
sns.countplot(x="Type of glass", data=df1)
plt.show()

# %%
df1["Type of glass"].value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of glass, dtype: int64

# %%
# Splitting the dataset as features (X) and labels (y)

# %%
X=df2
y=df1["Type of glass"]
y.value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of glass, dtype: int64

# %%
X.describe()
# Out:
#        Refractive index      Sodium   Magnesium    Aluminum       Silicon  \
# count      2.130000e+02  213.000000  213.000000  213.000000  2.130000e+02
# mean       8.691398e-04    2.067199    9.654754    0.879782  5.513911e+22
# std        2.716891e-18    0.033187    5.565505    0.202393  7.166394e+21
# min        8.691398e-04    1.945130    0.000000    0.255052  3.307500e+22
# 25%        8.691398e-04    2.047221    5.211366    0.787797  5.124553e+22
# 50%        8.691398e-04    2.063950   12.634541    0.863337  5.599121e+22
# 75%        8.691398e-04    2.085271   13.438588    0.972916  5.896871e+22
# max        8.691398e-04    2.207901   16.162453    1.518462  8.742176e+22
#
#         Potassium     Calcium      Barium        Iron
# count  213.000000  213.000000  213.000000  213.000000
# mean     0.279472    0.703740    0.019347    0.018832
# std      0.172163    0.005557    0.042519    0.027670
# min      0.000000    0.678193    0.000000    0.000000
# ...

# %%
# Standard Scaler: Scaling the variables

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
X1=scale.fit_transform(X)
X2=pd.DataFrame(X1,columns=X.columns)
X2
# Out:
#      Refractive index    Sodium  Magnesium  Aluminum   Silicon  Potassium  \
# 0                 0.0  0.616990   0.681474 -0.081445  0.038252   0.268575
# 1                 0.0  0.184792   0.620552  0.286720  0.394607   0.011888
# 2                 0.0 -0.210310   0.793249 -0.232162 -0.121300   0.496129
# 3                 0.0 -0.135420   0.706078 -0.342629  0.521438   0.447821
# 4                 0.0 -0.745389   0.693759  0.442150  0.366668   0.656025
# ..                ...       ...        ...       ...       ...        ...
# 208               0.0  0.909819  -1.738836  2.415517 -0.121300  -1.195502
# 209               0.0  1.787436  -1.738836  1.104938  0.493096  -1.627123
# 210               0.0  1.162750  -1.738836  1.155073  1.017262  -1.627123
# 211               0.0  1.185528  -1.738836  1.020265  1.306184  -1.627123
# 212               0.0  1.013820  -1.738836  1.253886  0.927811  -1.627123
#
#       Calcium    Barium      Iron
# 0   -0.882521 -0.456097 -0.682180
# ...

# %%
# Model building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
# Random state:

# %%
from sklearn.model_selection import train_test_split
maxAcc=0
for i in range(1000):
    X_train,X_test,y_train,y_test = train_test_split(X2,y, test_size=0.3,random_state=i)
    LR=LogisticRegression()
    build=LR.fit(X_train,y_train)
    y_pred=build.predict(X_test)
    Acc=accuracy_score(y_pred,y_test)
    if Acc>maxAcc:
        maxAcc=Acc
        random=i
print(f'Max accuracy: {maxAcc}')
print(f'Best_random_state: {random}')
# Out:
# Max accuracy: 0.8125
# Best_random_state: 134
